# %%
import getpass
user_id = getpass.getuser()

import sys
sys.path.append(f"/home/{user_id}/MIMIC-IV/")

import os 
import pandas as pd

# %%
base_path = f"/home/{user_id}/MIMIC-IV/"

# %% [markdown]
# # Explore hosp dataset

# %%
for file in os.listdir(os.path.join(base_path, "hosp")):
    if file.endswith("csv"):
        print(f"file is: {file}")
        df = pd.read_csv(os.path.join(base_path, "hosp", file), nrows=10)
        display(df)
# Out:
# file is: labevents.csv
#    labevent_id  subject_id  hadm_id  specimen_id  itemid order_provider_id  \
# 0            1    10000032      NaN     45421181   51237            P28Z0X
# 1            2    10000032      NaN     45421181   51274            P28Z0X
# 2            3    10000032      NaN     52958335   50853            P28Z0X
# 3            4    10000032      NaN     52958335   50861            P28Z0X
# 4            5    10000032      NaN     52958335   50862            P28Z0X
# 5            6    10000032      NaN     52958335   50863            P28Z0X
# 6            7    10000032      NaN     52958335   50864            P28Z0X
# 7            8    10000032      NaN     52958335   50868            P28Z0X
# 8            9    10000032      NaN     52958335   50878            P28Z0X
# 9           10    10000032      NaN     52958335   50882            P28Z0X
#
#              charttime            storetime value  valuenum valueuom  \
# ...

# %% [markdown]
# # Explore icu dataset

# %%
for file in os.listdir(os.path.join(base_path, "icu")):
    if file.endswith("csv"):
        print(f"file is: {file}")
        df = pd.read_csv(os.path.join(base_path, "icu", file), nrows=10)
        display(df)
# Out:
# file is: chartevents.csv
#    subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0    10000032  29079034  39553978         47007  2180-07-23 21:01:00
# 1    10000032  29079034  39553978         47007  2180-07-23 21:01:00
# 2    10000032  29079034  39553978         47007  2180-07-23 21:01:00
# 3    10000032  29079034  39553978         47007  2180-07-23 22:00:00
# 4    10000032  29079034  39553978         47007  2180-07-23 22:00:00
# 5    10000032  29079034  39553978         47007  2180-07-23 22:00:00
# 6    10000032  29079034  39553978         47007  2180-07-23 22:00:00
# 7    10000032  29079034  39553978         47007  2180-07-23 22:00:00
# 8    10000032  29079034  39553978         47007  2180-07-23 22:00:00
# 9    10000032  29079034  39553978         66056  2180-07-23 19:00:00
#
#              storetime  itemid  value  valuenum  valueuom  warning
# 0  2180-07-23 22:15:00  220179     82        82      mmHg        0
# ...

# %%
from collections import Counter

prescription_path = "/home/wanxinli/MIMIC-IV/hosp/prescriptions.csv"
df = pd.read_csv(prescription_path)
drug_counter = Counter(df['drug'])
drug_counter = {k: v for k, v in sorted(drug_counter.items(), key=lambda item: item[1], reverse=True)}
print(drug_counter)
# Out:
# /tmp/ipykernel_1128243/893760161.py:4: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(prescription_path)
# ...

# %%
# The previous code block suggests the use of Insolin is the most common drug in prescription
