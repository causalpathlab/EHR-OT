# %%
import os

# %%
folder_path = '/home/wanxinli/OTTEHR/outputs/mimiciii'

for file in os.listdir(folder_path):
    if file.startswith('exp4_'):
        file_path = os.path.join(folder_path, file)
        new_file_path = os.path.join(folder_path, file[5:])
        print(new_file_path)
        os.rename(file_path, new_file_path)
# Out:
# /home/wanxinli/OTTEHR/outputs/mimiciii/marital_status_DIVORCED2WIDOWED_OT.csv
# /home/wanxinli/OTTEHR/outputs/mimiciii/insurance_Medicare2Government_RSD.csv
# /home/wanxinli/OTTEHR/outputs/mimiciii/insurance_Medicare2Private_GFK.csv
# /home/wanxinli/OTTEHR/outputs/mimiciii/insurance_Private2Medicare_GWOT.csv
# /home/wanxinli/OTTEHR/outputs/mimiciii/insurance_source_RMSE_bound.pdf
# /home/wanxinli/OTTEHR/outputs/mimiciii/insurance_Government2Self_Pay_TCA.csv
# /home/wanxinli/OTTEHR/outputs/mimiciii/marital_status_DIVORCED2MARRIED_CA.csv
# /home/wanxinli/OTTEHR/outputs/mimiciii/insurance_Medicaid2Government_GWOT.csv
# /home/wanxinli/OTTEHR/outputs/mimiciii/marital_status_SEPARATED2MARRIED_TCA.csv
# /home/wanxinli/OTTEHR/outputs/mimiciii/insurance_Medicare2Government_TCA.csv
# /home/wanxinli/OTTEHR/outputs/mimiciii/marital_status_SEPARATED2DIVORCED_deepJDOT.csv
# /home/wanxinli/OTTEHR/outputs/mimiciii/marital_status_MARRIED2SINGLE_OT_equity.csv
# ...
