# %%
import sys
sys.path.append("/home/wanxinli/EHR-OT/")

from common import *
import numpy as np
from mimic_common import *
import matplotlib.pyplot as plt
import os

# %%
plt.xlim((-5, 20)) # restricts x axis from 0 to 25
plt.ylim((-5, 20)) # restricts x axis from 0 to 25
plt.plot([0, 20], [0, 20], color='black') # plots line y = x
ax = plt.gca()
# Move left y-axis and bottom x-axis to centre, passing through (0,0)
ax.spines['left'].set_position(('data', 0))
ax.spines['bottom'].set_position(('data', 0))

# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_tick_params(labelbottom=False)
ax.yaxis.set_tick_params(labelleft=False)
ax.set_xticks([0, 10])
ax.set_yticks([])

x_coords = range(0,20)
y_coords = [x**2/8 for x in x_coords]

x_points = [1, 2, 3.5, 4, 8, 8.5, 9, 9.3, 9.5]
y_points = [x**2/8 for x in x_points]
plt.plot(x_coords, y_coords, color='black')
plt.scatter(x_points, y_points)
plt.axvline(x=10, linestyle='--')
x_sub = np.arange(10, 20, 0.01)
y1 = [x for x in x_sub]
y2 = [x**2/8 for x in x_sub]
plt.fill_between(x_sub, y1, y2, color='gray')
fig_path = os.path.join(mimic_output_dir, "target_error.png")
plt.savefig(fig_path)

plt.show()
